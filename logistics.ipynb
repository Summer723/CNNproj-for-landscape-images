# %%
pip install import-ipynb

# %%
pip install torchsummary

# %%
pip install torch

# %%
pip install torchinfo
# Out:
# Collecting torchinfo
#   Downloading torchinfo-1.7.1-py3-none-any.whl (22 kB)
# Installing collected packages: torchinfo
# Successfully installed torchinfo-1.7.1
# WARNING: You are using pip version 21.2.3; however, version 22.3 is available.
# You should consider upgrading via the '/Library/Frameworks/Python.framework/Versions/3.10/bin/python3.10 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install torchvision
# Out:
# Requirement already satisfied: torchvision in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (0.14.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from torchvision) (9.3.0)
# Requirement already satisfied: numpy in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from torchvision) (1.23.4)
# Requirement already satisfied: requests in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from torchvision) (2.28.1)
# Requirement already satisfied: torch in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from torchvision) (1.13.0)
# Requirement already satisfied: typing-extensions in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from torchvision) (4.4.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from requests->torchvision) (1.26.12)
# Requirement already satisfied: certifi>=2017.4.17 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from requests->torchvision) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from requests->torchvision) (3.4)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from requests->torchvision) (2.1.1)
# WARNING: You are using pip version 21.2.3; however, version 22.3 is available.
# You should consider upgrading via the '/Library/Frameworks/Python.framework/Versions/3.10/bin/python3.10 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install matplotlib

# %%
pip install pandas

# %%
pip install tensorboard
# Out:
# Collecting tensorboard
#   Downloading tensorboard-2.10.1-py3-none-any.whl (5.9 MB)
#      |████████████████████████████████| 5.9 MB 5.4 MB/s eta 0:00:01
# Collecting absl-py>=0.4
#   Downloading absl_py-1.3.0-py3-none-any.whl (124 kB)
#      |████████████████████████████████| 124 kB 29.9 MB/s eta 0:00:01
# Requirement already satisfied: requests<3,>=2.21.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from tensorboard) (2.28.1)
# Requirement already satisfied: setuptools>=41.0.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from tensorboard) (57.4.0)
# Collecting tensorboard-data-server<0.7.0,>=0.6.0
#   Downloading tensorboard_data_server-0.6.1-py3-none-any.whl (2.4 kB)
# Requirement already satisfied: numpy>=1.12.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from tensorboard) (1.23.4)
# Collecting grpcio>=1.24.3
#   Downloading grpcio-1.50.0.tar.gz (22.1 MB)
#      |████████████████████████████████| 22.1 MB 16.3 MB/s eta 0:00:01
# Collecting tensorboard-plugin-wit>=1.6.0
#   Downloading tensorboard_plugin_wit-1.8.1-py3-none-any.whl (781 kB)
#      |████████████████████████████████| 781 kB 67.2 MB/s eta 0:00:01
# Collecting google-auth<3,>=1.6.3
#   Downloading google_auth-2.14.0-py2.py3-none-any.whl (175 kB)
#      |████████████████████████████████| 175 kB 49.2 MB/s eta 0:00:01
# Collecting google-auth-oauthlib<0.5,>=0.4.1
#   Downloading google_auth_oauthlib-0.4.6-py2.py3-none-any.whl (18 kB)
# Collecting wheel>=0.26
#   Downloading wheel-0.37.1-py2.py3-none-any.whl (35 kB)
# Collecting markdown>=2.6.8
#   Downloading Markdown-3.4.1-py3-none-any.whl (93 kB)
#      |████████████████████████████████| 93 kB 9.1 MB/s  eta 0:00:01
# Collecting protobuf<3.20,>=3.9.2
#   Downloading protobuf-3.19.6-py2.py3-none-any.whl (162 kB)
#      |████████████████████████████████| 162 kB 37.9 MB/s eta 0:00:01
# Collecting werkzeug>=1.0.1
#   Downloading Werkzeug-2.2.2-py3-none-any.whl (232 kB)
#      |████████████████████████████████| 232 kB 65.7 MB/s eta 0:00:01
# Collecting cachetools<6.0,>=2.0.0
#   Downloading cachetools-5.2.0-py3-none-any.whl (9.3 kB)
# Collecting pyasn1-modules>=0.2.1
#   Using cached pyasn1_modules-0.2.8-py2.py3-none-any.whl (155 kB)
# Collecting rsa<5,>=3.1.4
#   Downloading rsa-4.9-py3-none-any.whl (34 kB)
# Requirement already satisfied: six>=1.9.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard) (1.16.0)
# Collecting requests-oauthlib>=0.7.0
#   Downloading requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# Collecting pyasn1<0.5.0,>=0.4.6
#   Using cached pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard) (1.26.12)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard) (2021.10.8)
# Collecting oauthlib>=3.0.0
#   Downloading oauthlib-3.2.2-py3-none-any.whl (151 kB)
#      |████████████████████████████████| 151 kB 36.3 MB/s eta 0:00:01
# Requirement already satisfied: MarkupSafe>=2.1.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from werkzeug>=1.0.1->tensorboard) (2.1.1)
# Using legacy 'setup.py install' for grpcio, since package 'wheel' is not installed.
# Installing collected packages: pyasn1, rsa, pyasn1-modules, oauthlib, cachetools, requests-oauthlib, google-auth, wheel, werkzeug, tensorboard-plugin-wit, tensorboard-data-server, protobuf, markdown, grpcio, google-auth-oauthlib, absl-py, tensorboard
#     Running setup.py install for grpcio ... error
#     ERROR: Command errored out with exit status 1:
#      command: /Library/Frameworks/Python.framework/Versions/3.10/bin/python3.10 -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/n3/gktccr_97278_m89q24kbjx80000gn/T/pip-install-jpnjh75i/grpcio_24fe0bfdd51e47d98e1d829148fb0a6c/setup.py'"'"'; __file__='"'"'/private/var/folders/n3/gktccr_97278_m89q24kbjx80000gn/T/pip-install-jpnjh75i/grpcio_24fe0bfdd51e47d98e1d829148fb0a6c/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record /private/var/folders/n3/gktccr_97278_m89q24kbjx80000gn/T/pip-record-73tcskf_/install-record.txt --single-version-externally-managed --compile --install-headers /Library/Frameworks/Python.framework/Versions/3.10/include/python3.10/grpcio
#          cwd: /private/var/folders/n3/gktccr_97278_m89q24kbjx80000gn/T/pip-install-jpnjh75i/grpcio_24fe0bfdd51e47d98e1d829148fb0a6c/
#     Complete output (699 lines):
#     ASM Builds for BoringSSL currently not supported on: macosx-10.9-universal2
#     Found cython-generated files...
#     running install
#     running build
#     running build_py
#     running build_project_metadata
#     creating python_build
#     creating python_build/lib.macosx-10.10-universal2-3.10
#     creating python_build/lib.macosx-10.10-universal2-3.10/grpc
#     copying src/python/grpcio/grpc/_compression.py -> python_build/lib.macosx-10.10-universal2-3.10/grpc
#     copying src/python/grpcio/grpc/_channel.py -> python_build/lib.macosx-10.10-universal2-3.10/grpc
#     copying src/python/grpcio/grpc/_common.py -> python_build/lib.macosx-10.10-universal2-3.10/grpc
#     copying src/python/grpcio/grpc/__init__.py -> python_build/lib.macosx-10.10-universal2-3.10/grpc
#     copying src/python/grpcio/grpc/_utilities.py -> python_build/lib.macosx-10.10-universal2-3.10/grpc
#     copying src/python/grpcio/grpc/_simple_stubs.py -> python_build/lib.macosx-10.10-universal2-3.10/grpc
#     copying src/python/grpcio/grpc/_plugin_wrapping.py -> python_build/lib.macosx-10.10-universal2-3.10/grpc
#     copying src/python/grpcio/grpc/_interceptor.py -> python_build/lib.macosx-10.10-universal2-3.10/grpc
#     copying src/python/grpcio/grpc/_grpcio_metadata.py -> python_build/lib.macosx-10.10-universal2-3.10/grpc
#     copying src/python/grpcio/grpc/_server.py -> python_build/lib.macosx-10.10-universal2-3.10/grpc
#     copying src/python/grpcio/grpc/_runtime_protos.py -> python_build/lib.macosx-10.10-universal2-3.10/grpc
#     copying src/python/grpcio/grpc/_auth.py -> python_build/lib.macosx-10.10-universal2-3.10/grpc
#     creating python_build/lib.macosx-10.10-universal2-3.10/grpc/beta
#     copying src/python/grpcio/grpc/beta/_server_adaptations.py -> python_build/lib.macosx-10.10-universal2-3.10/grpc/beta
#     copying src/python/grpcio/grpc/beta/interfaces.py -> python_build/lib.macosx-10.10-universal2-3.10/grpc/beta
#     copying src/python/grpcio/grpc/beta/_metadata.py -> python_build/lib.macosx-10.10-universal2-3.10/grpc/beta
#     copying src/python/grpcio/grpc/beta/__init__.py -> python_build/lib.macosx-10.10-universal2-3.10/grpc/beta
#     copying src/python/grpcio/grpc/beta/utilities.py -> python_build/lib.macosx-10.10-universal2-3.10/grpc/beta
#     copying src/python/grpcio/grpc/beta/implementations.py -> python_build/lib.macosx-10.10-universal2-3.10/grpc/beta
#     copying src/python/grpcio/grpc/beta/_client_adaptations.py -> python_build/lib.macosx-10.10-universal2-3.10/grpc/beta
#     creating python_build/lib.macosx-10.10-universal2-3.10/grpc/experimental
#     copying src/python/grpcio/grpc/experimental/gevent.py -> python_build/lib.macosx-10.10-universal2-3.10/grpc/experimental
#     copying src/python/grpcio/grpc/experimental/__init__.py -> python_build/lib.macosx-10.10-universal2-3.10/grpc/experimental
#     copying src/python/grpcio/grpc/experimental/session_cache.py -> python_build/lib.macosx-10.10-universal2-3.10/grpc/experimental
#     creating python_build/lib.macosx-10.10-universal2-3.10/grpc/framework
#     copying src/python/grpcio/grpc/framework/__init__.py -> python_build/lib.macosx-10.10-universal2-3.10/grpc/framework
#     creating python_build/lib.macosx-10.10-universal2-3.10/grpc/aio
#     copying src/python/grpcio/grpc/aio/_base_server.py -> python_build/lib.macosx-10.10-universal2-3.10/grpc/aio
#     copying src/python/grpcio/grpc/aio/_metadata.py -> python_build/lib.macosx-10.10-universal2-3.10/grpc/aio
#     copying src/python/grpcio/grpc/aio/_typing.py -> python_build/lib.macosx-10.10-universal2-3.10/grpc/aio
#     copying src/python/grpcio/grpc/aio/_call.py -> python_build/lib.macosx-10.10-universal2-3.10/grpc/aio
#     copying src/python/grpcio/grpc/aio/_channel.py -> python_build/lib.macosx-10.10-universal2-3.10/grpc/aio
#     copying src/python/grpcio/grpc/aio/__init__.py -> python_build/lib.macosx-10.10-universal2-3.10/grpc/aio
#     copying src/python/grpcio/grpc/aio/_base_channel.py -> python_build/lib.macosx-10.10-universal2-3.10/grpc/aio
#     copying src/python/grpcio/grpc/aio/_interceptor.py -> python_build/lib.macosx-10.10-universal2-3.10/grpc/aio
#     copying src/python/grpcio/grpc/aio/_server.py -> python_build/lib.macosx-10.10-universal2-3.10/grpc/aio
#     copying src/python/grpcio/grpc/aio/_base_call.py -> python_build/lib.macosx-10.10-universal2-3.10/grpc/aio
#     copying src/python/grpcio/grpc/aio/_utils.py -> python_build/lib.macosx-10.10-universal2-3.10/grpc/aio
#     creating python_build/lib.macosx-10.10-universal2-3.10/grpc/_cython
#     copying src/python/grpcio/grpc/_cython/__init__.py -> python_build/lib.macosx-10.10-universal2-3.10/grpc/_cython
#     creating python_build/lib.macosx-10.10-universal2-3.10/grpc/experimental/aio
#     copying src/python/grpcio/grpc/experimental/aio/__init__.py -> python_build/lib.macosx-10.10-universal2-3.10/grpc/experimental/aio
#     creating python_build/lib.macosx-10.10-universal2-3.10/grpc/framework/foundation
#     copying src/python/grpcio/grpc/framework/foundation/callable_util.py -> python_build/lib.macosx-10.10-universal2-3.10/grpc/framework/foundation
#     copying src/python/grpcio/grpc/framework/foundation/abandonment.py -> python_build/lib.macosx-10.10-universal2-3.10/grpc/framework/foundation
#     copying src/python/grpcio/grpc/framework/foundation/__init__.py -> python_build/lib.macosx-10.10-universal2-3.10/grpc/framework/foundation
#     copying src/python/grpcio/grpc/framework/foundation/stream.py -> python_build/lib.macosx-10.10-universal2-3.10/grpc/framework/foundation
#     copying src/python/grpcio/grpc/framework/foundation/stream_util.py -> python_build/lib.macosx-10.10-universal2-3.10/grpc/framework/foundation
#     copying src/python/grpcio/grpc/framework/foundation/future.py -> python_build/lib.macosx-10.10-universal2-3.10/grpc/framework/foundation
#     copying src/python/grpcio/grpc/framework/foundation/logging_pool.py -> python_build/lib.macosx-10.10-universal2-3.10/grpc/framework/foundation
#     creating python_build/lib.macosx-10.10-universal2-3.10/grpc/framework/common
#     copying src/python/grpcio/grpc/framework/common/style.py -> python_build/lib.macosx-10.10-universal2-3.10/grpc/framework/common
#     copying src/python/grpcio/grpc/framework/common/cardinality.py -> python_build/lib.macosx-10.10-universal2-3.10/grpc/framework/common
#     copying src/python/grpcio/grpc/framework/common/__init__.py -> python_build/lib.macosx-10.10-universal2-3.10/grpc/framework/common
#     creating python_build/lib.macosx-10.10-universal2-3.10/grpc/framework/interfaces
#     copying src/python/grpcio/grpc/framework/interfaces/__init__.py -> python_build/lib.macosx-10.10-universal2-3.10/grpc/framework/interfaces
#     creating python_build/lib.macosx-10.10-universal2-3.10/grpc/framework/interfaces/face
#     copying src/python/grpcio/grpc/framework/interfaces/face/__init__.py -> python_build/lib.macosx-10.10-universal2-3.10/grpc/framework/interfaces/face
#     copying src/python/grpcio/grpc/framework/interfaces/face/utilities.py -> python_build/lib.macosx-10.10-universal2-3.10/grpc/framework/interfaces/face
#     copying src/python/grpcio/grpc/framework/interfaces/face/face.py -> python_build/lib.macosx-10.10-universal2-3.10/grpc/framework/interfaces/face
#     creating python_build/lib.macosx-10.10-universal2-3.10/grpc/framework/interfaces/base
#     copying src/python/grpcio/grpc/framework/interfaces/base/__init__.py -> python_build/lib.macosx-10.10-universal2-3.10/grpc/framework/interfaces/base
#     copying src/python/grpcio/grpc/framework/interfaces/base/utilities.py -> python_build/lib.macosx-10.10-universal2-3.10/grpc/framework/interfaces/base
#     copying src/python/grpcio/grpc/framework/interfaces/base/base.py -> python_build/lib.macosx-10.10-universal2-3.10/grpc/framework/interfaces/base
#     creating python_build/lib.macosx-10.10-universal2-3.10/grpc/_cython/_cygrpc
#     copying src/python/grpcio/grpc/_cython/_cygrpc/__init__.py -> python_build/lib.macosx-10.10-universal2-3.10/grpc/_cython/_cygrpc
#     creating python_build/lib.macosx-10.10-universal2-3.10/grpc/_cython/_credentials
#     copying src/python/grpcio/grpc/_cython/_credentials/roots.pem -> python_build/lib.macosx-10.10-universal2-3.10/grpc/_cython/_credentials
#     running build_ext
#     Found cython-generated files...
#     building 'grpc._cython.cygrpc' extension
#     creating python_build/temp.macosx-10.10-universal2-3.10
#     creating python_build/temp.macosx-10.10-universal2-3.10/src
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/filters
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/filters/census
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/filters/channel_idle
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/filters/client_channel
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/filters/client_channel/health
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/filters/client_channel/lb_policy
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/filters/client_channel/lb_policy/grpclb
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/filters/client_channel/lb_policy/outlier_detection
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/filters/client_channel/lb_policy/pick_first
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/filters/client_channel/lb_policy/priority
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/filters/client_channel/lb_policy/ring_hash
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/filters/client_channel/lb_policy/rls
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/filters/client_channel/lb_policy/round_robin
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/filters/client_channel/lb_policy/weighted_target
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/filters/client_channel/lb_policy/xds
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/filters/client_channel/resolver
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/filters/client_channel/resolver/binder
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/filters/client_channel/resolver/dns
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/filters/client_channel/resolver/dns/c_ares
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/filters/client_channel/resolver/dns/native
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/filters/client_channel/resolver/fake
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/filters/client_channel/resolver/google_c2p
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/filters/client_channel/resolver/sockaddr
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/filters/client_channel/resolver/xds
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/filters/deadline
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/filters/fault_injection
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/filters/http
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/filters/http/client
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/filters/http/message_compress
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/filters/http/server
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/filters/message_size
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/filters/rbac
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/filters/server_config_selector
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/transport
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/transport/chttp2
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/transport/chttp2/alpn
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/transport/chttp2/client
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/transport/chttp2/server
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/transport/chttp2/transport
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/transport/inproc
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upb-generated
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upb-generated/envoy
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upb-generated/envoy/admin
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upb-generated/envoy/admin/v3
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upb-generated/envoy/annotations
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upb-generated/envoy/config
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upb-generated/envoy/config/accesslog
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upb-generated/envoy/config/accesslog/v3
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upb-generated/envoy/config/bootstrap
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upb-generated/envoy/config/bootstrap/v3
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upb-generated/envoy/config/cluster
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upb-generated/envoy/config/cluster/v3
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upb-generated/envoy/config/common
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upb-generated/envoy/config/common/matcher
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upb-generated/envoy/config/common/matcher/v3
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upb-generated/envoy/config/core
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upb-generated/envoy/config/core/v3
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upb-generated/envoy/config/endpoint
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upb-generated/envoy/config/endpoint/v3
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upb-generated/envoy/config/listener
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upb-generated/envoy/config/listener/v3
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upb-generated/envoy/config/metrics
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upb-generated/envoy/config/metrics/v3
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upb-generated/envoy/config/overload
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upb-generated/envoy/config/overload/v3
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upb-generated/envoy/config/rbac
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upb-generated/envoy/config/rbac/v3
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upb-generated/envoy/config/route
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upb-generated/envoy/config/route/v3
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upb-generated/envoy/config/tap
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upb-generated/envoy/config/tap/v3
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upb-generated/envoy/config/trace
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upb-generated/envoy/config/trace/v3
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upb-generated/envoy/extensions
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upb-generated/envoy/extensions/clusters
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upb-generated/envoy/extensions/clusters/aggregate
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upb-generated/envoy/extensions/clusters/aggregate/v3
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upb-generated/envoy/extensions/filters
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upb-generated/envoy/extensions/filters/common
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upb-generated/envoy/extensions/filters/common/fault
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upb-generated/envoy/extensions/filters/common/fault/v3
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upb-generated/envoy/extensions/filters/http
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upb-generated/envoy/extensions/filters/http/fault
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upb-generated/envoy/extensions/filters/http/fault/v3
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upb-generated/envoy/extensions/filters/http/rbac
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upb-generated/envoy/extensions/filters/http/rbac/v3
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upb-generated/envoy/extensions/filters/http/router
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upb-generated/envoy/extensions/filters/http/router/v3
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upb-generated/envoy/extensions/filters/network
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upb-generated/envoy/extensions/filters/network/http_connection_manager
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upb-generated/envoy/extensions/filters/network/http_connection_manager/v3
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upb-generated/envoy/extensions/load_balancing_policies
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upb-generated/envoy/extensions/load_balancing_policies/ring_hash
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upb-generated/envoy/extensions/load_balancing_policies/ring_hash/v3
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upb-generated/envoy/extensions/load_balancing_policies/wrr_locality
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upb-generated/envoy/extensions/load_balancing_policies/wrr_locality/v3
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upb-generated/envoy/extensions/transport_sockets
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upb-generated/envoy/extensions/transport_sockets/tls
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upb-generated/envoy/extensions/transport_sockets/tls/v3
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upb-generated/envoy/service
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upb-generated/envoy/service/discovery
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upb-generated/envoy/service/discovery/v3
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upb-generated/envoy/service/load_stats
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upb-generated/envoy/service/load_stats/v3
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upb-generated/envoy/service/status
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upb-generated/envoy/service/status/v3
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upb-generated/envoy/type
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upb-generated/envoy/type/http
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upb-generated/envoy/type/http/v3
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upb-generated/envoy/type/matcher
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upb-generated/envoy/type/matcher/v3
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upb-generated/envoy/type/metadata
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upb-generated/envoy/type/metadata/v3
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upb-generated/envoy/type/tracing
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upb-generated/envoy/type/tracing/v3
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upb-generated/envoy/type/v3
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upb-generated/google
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upb-generated/google/api
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upb-generated/google/api/expr
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upb-generated/google/api/expr/v1alpha1
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upb-generated/google/protobuf
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upb-generated/google/rpc
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upb-generated/opencensus
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upb-generated/opencensus/proto
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upb-generated/opencensus/proto/trace
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upb-generated/opencensus/proto/trace/v1
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upb-generated/src
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upb-generated/src/proto
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upb-generated/src/proto/grpc
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upb-generated/src/proto/grpc/gcp
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upb-generated/src/proto/grpc/health
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upb-generated/src/proto/grpc/health/v1
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upb-generated/src/proto/grpc/lb
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upb-generated/src/proto/grpc/lb/v1
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upb-generated/src/proto/grpc/lookup
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upb-generated/src/proto/grpc/lookup/v1
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upb-generated/udpa
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upb-generated/udpa/annotations
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upb-generated/validate
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upb-generated/xds
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upb-generated/xds/annotations
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upb-generated/xds/annotations/v3
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upb-generated/xds/core
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upb-generated/xds/core/v3
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upb-generated/xds/data
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upb-generated/xds/data/orca
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upb-generated/xds/data/orca/v3
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upb-generated/xds/service
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upb-generated/xds/service/orca
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upb-generated/xds/service/orca/v3
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upb-generated/xds/type
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upb-generated/xds/type/matcher
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upb-generated/xds/type/matcher/v3
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upb-generated/xds/type/v3
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upbdefs-generated
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upbdefs-generated/envoy
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upbdefs-generated/envoy/admin
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upbdefs-generated/envoy/admin/v3
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upbdefs-generated/envoy/annotations
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upbdefs-generated/envoy/config
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upbdefs-generated/envoy/config/accesslog
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upbdefs-generated/envoy/config/accesslog/v3
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upbdefs-generated/envoy/config/bootstrap
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upbdefs-generated/envoy/config/bootstrap/v3
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upbdefs-generated/envoy/config/cluster
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upbdefs-generated/envoy/config/cluster/v3
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upbdefs-generated/envoy/config/common
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upbdefs-generated/envoy/config/common/matcher
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upbdefs-generated/envoy/config/common/matcher/v3
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upbdefs-generated/envoy/config/core
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upbdefs-generated/envoy/config/core/v3
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upbdefs-generated/envoy/config/endpoint
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upbdefs-generated/envoy/config/endpoint/v3
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upbdefs-generated/envoy/config/listener
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upbdefs-generated/envoy/config/listener/v3
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upbdefs-generated/envoy/config/metrics
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upbdefs-generated/envoy/config/metrics/v3
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upbdefs-generated/envoy/config/overload
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upbdefs-generated/envoy/config/overload/v3
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upbdefs-generated/envoy/config/rbac
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upbdefs-generated/envoy/config/rbac/v3
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upbdefs-generated/envoy/config/route
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upbdefs-generated/envoy/config/route/v3
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upbdefs-generated/envoy/config/tap
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upbdefs-generated/envoy/config/tap/v3
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upbdefs-generated/envoy/config/trace
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upbdefs-generated/envoy/config/trace/v3
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upbdefs-generated/envoy/extensions
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upbdefs-generated/envoy/extensions/clusters
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upbdefs-generated/envoy/extensions/clusters/aggregate
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upbdefs-generated/envoy/extensions/clusters/aggregate/v3
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upbdefs-generated/envoy/extensions/filters
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upbdefs-generated/envoy/extensions/filters/common
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upbdefs-generated/envoy/extensions/filters/common/fault
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upbdefs-generated/envoy/extensions/filters/common/fault/v3
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upbdefs-generated/envoy/extensions/filters/http
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upbdefs-generated/envoy/extensions/filters/http/fault
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upbdefs-generated/envoy/extensions/filters/http/fault/v3
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upbdefs-generated/envoy/extensions/filters/http/rbac
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upbdefs-generated/envoy/extensions/filters/http/rbac/v3
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upbdefs-generated/envoy/extensions/filters/http/router
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upbdefs-generated/envoy/extensions/filters/http/router/v3
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upbdefs-generated/envoy/extensions/filters/network
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upbdefs-generated/envoy/extensions/filters/network/http_connection_manager
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upbdefs-generated/envoy/extensions/filters/network/http_connection_manager/v3
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upbdefs-generated/envoy/extensions/transport_sockets
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upbdefs-generated/envoy/extensions/transport_sockets/tls
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upbdefs-generated/envoy/extensions/transport_sockets/tls/v3
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upbdefs-generated/envoy/service
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upbdefs-generated/envoy/service/discovery
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upbdefs-generated/envoy/service/discovery/v3
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upbdefs-generated/envoy/service/load_stats
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upbdefs-generated/envoy/service/load_stats/v3
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upbdefs-generated/envoy/service/status
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upbdefs-generated/envoy/service/status/v3
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upbdefs-generated/envoy/type
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upbdefs-generated/envoy/type/http
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upbdefs-generated/envoy/type/http/v3
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upbdefs-generated/envoy/type/matcher
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upbdefs-generated/envoy/type/matcher/v3
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upbdefs-generated/envoy/type/metadata
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upbdefs-generated/envoy/type/metadata/v3
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upbdefs-generated/envoy/type/tracing
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upbdefs-generated/envoy/type/tracing/v3
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upbdefs-generated/envoy/type/v3
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upbdefs-generated/google
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upbdefs-generated/google/api
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upbdefs-generated/google/api/expr
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upbdefs-generated/google/api/expr/v1alpha1
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upbdefs-generated/google/protobuf
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upbdefs-generated/google/rpc
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upbdefs-generated/opencensus
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upbdefs-generated/opencensus/proto
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upbdefs-generated/opencensus/proto/trace
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upbdefs-generated/opencensus/proto/trace/v1
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upbdefs-generated/src
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upbdefs-generated/src/proto
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upbdefs-generated/src/proto/grpc
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upbdefs-generated/src/proto/grpc/lookup
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upbdefs-generated/src/proto/grpc/lookup/v1
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upbdefs-generated/udpa
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upbdefs-generated/udpa/annotations
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upbdefs-generated/validate
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upbdefs-generated/xds
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upbdefs-generated/xds/annotations
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upbdefs-generated/xds/annotations/v3
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upbdefs-generated/xds/core
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upbdefs-generated/xds/core/v3
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upbdefs-generated/xds/type
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upbdefs-generated/xds/type/matcher
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upbdefs-generated/xds/type/matcher/v3
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/upbdefs-generated/xds/type/v3
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/ext/xds
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/lib
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/lib/address_utils
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/lib/backoff
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/lib/channel
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/lib/compression
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/lib/config
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/lib/debug
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/lib/event_engine
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/lib/event_engine/executor
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/lib/event_engine/posix_engine
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/lib/event_engine/windows
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/lib/experiments
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/lib/gpr
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/lib/gprpp
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/lib/handshaker
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/lib/http
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/lib/iomgr
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/lib/json
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/lib/load_balancing
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/lib/matchers
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/lib/promise
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/lib/resolver
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/lib/resource_quota
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/lib/security
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/lib/security/authorization
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/lib/security/certificate_provider
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/lib/security/context
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/lib/security/credentials
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/lib/security/credentials/alts
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/lib/security/credentials/composite
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/lib/security/credentials/external
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/lib/security/credentials/fake
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/lib/security/credentials/google_default
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/lib/security/credentials/iam
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/lib/security/credentials/insecure
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/lib/security/credentials/jwt
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/lib/security/credentials/local
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/lib/security/credentials/oauth2
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/lib/security/credentials/plugin
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/lib/security/credentials/ssl
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/lib/security/credentials/tls
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/lib/security/credentials/xds
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/lib/security/security_connector
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/lib/security/security_connector/alts
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/lib/security/security_connector/fake
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/lib/security/security_connector/insecure
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/lib/security/security_connector/local
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/lib/security/security_connector/ssl
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/lib/security/security_connector/tls
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/lib/security/transport
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/lib/security/util
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/lib/service_config
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/lib/slice
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/lib/surface
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/lib/transport
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/lib/uri
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/plugin_registry
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/tsi
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/tsi/alts
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/tsi/alts/crypt
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/tsi/alts/frame_protector
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/tsi/alts/handshaker
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/tsi/alts/zero_copy_frame_protector
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/tsi/ssl
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/tsi/ssl/key_logging
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/core/tsi/ssl/session_cache
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/python
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/python/grpcio
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/python/grpcio/grpc
#     creating python_build/temp.macosx-10.10-universal2-3.10/src/python/grpcio/grpc/_cython
# ...
#
#     You have not agreed to the Xcode license agreements, please run 'sudo xcodebuild -license' from within a Terminal window to review and agree to the Xcode license agreements.
#     clang -Wno-unused-result -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -arch arm64 -arch x86_64 -g -D_WIN32_WINNT=1536 -DGRPC_XDS_USER_AGENT_NAME_SUFFIX="Python" -DGRPC_XDS_USER_AGENT_VERSION_SUFFIX="1.50.0" -DOPENSSL_NO_ASM=1 -DGPR_BACKWARDS_COMPATIBILITY_MODE=1 -DHAVE_CONFIG_H=1 -DGRPC_ENABLE_FORK_SUPPORT=1 -DPyMODINIT_FUNC=extern "C" __attribute__((visibility ("default"))) PyObject* -DGRPC_POSIX_FORK_ALLOW_PTHREAD_ATFORK=1 -Isrc/python/grpcio -Iinclude -I. -Ithird_party/abseil-cpp -Ithird_party/address_sorting/include -Ithird_party/cares/cares/include -Ithird_party/cares -Ithird_party/cares/cares -Ithird_party/cares/config_darwin -Ithird_party/re2 -Ithird_party/boringssl-with-bazel/src/include -Ithird_party/upb -Isrc/core/ext/upb-generated -Isrc/core/ext/upbdefs-generated -Ithird_party/xxhash -Ithird_party/zlib -I/Library/Frameworks/Python.framework/Versions/3.10/include/python3.10 -c third_party/cares/cares/src/lib/ares__parse_into_addrinfo.c -o python_build/temp.macosx-10.10-universal2-3.10/third_party/cares/cares/src/lib/ares__parse_into_addrinfo.o -std=c++14 -stdlib=libc++ -fvisibility=hidden -fno-wrapv -fno-exceptions -DHAVE_UNISTD_H -pthread
#
#     You have not agreed to the Xcode license agreements, please run 'sudo xcodebuild -license' from within a Terminal window to review and agree to the Xcode license agreements.
#     clang -Wno-unused-result -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -arch arm64 -arch x86_64 -g -D_WIN32_WINNT=1536 -DGRPC_XDS_USER_AGENT_NAME_SUFFIX="Python" -DGRPC_XDS_USER_AGENT_VERSION_SUFFIX="1.50.0" -DOPENSSL_NO_ASM=1 -DGPR_BACKWARDS_COMPATIBILITY_MODE=1 -DHAVE_CONFIG_H=1 -DGRPC_ENABLE_FORK_SUPPORT=1 -DPyMODINIT_FUNC=extern "C" __attribute__((visibility ("default"))) PyObject* -DGRPC_POSIX_FORK_ALLOW_PTHREAD_ATFORK=1 -Isrc/python/grpcio -Iinclude -I. -Ithird_party/abseil-cpp -Ithird_party/address_sorting/include -Ithird_party/cares/cares/include -Ithird_party/cares -Ithird_party/cares/cares -Ithird_party/cares/config_darwin -Ithird_party/re2 -Ithird_party/boringssl-with-bazel/src/include -Ithird_party/upb -Isrc/core/ext/upb-generated -Isrc/core/ext/upbdefs-generated -Ithird_party/xxhash -Ithird_party/zlib -I/Library/Frameworks/Python.framework/Versions/3.10/include/python3.10 -c third_party/cares/cares/src/lib/ares_platform.c -o python_build/temp.macosx-10.10-universal2-3.10/third_party/cares/cares/src/lib/ares_platform.o -std=c++14 -stdlib=libc++ -fvisibility=hidden -fno-wrapv -fno-exceptions -DHAVE_UNISTD_H -pthread
#
#     You have not agreed to the Xcode license agreements, please run 'sudo xcodebuild -license' from within a Terminal window to review and agree to the Xcode license agreements.
#     clang -Wno-unused-result -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -arch arm64 -arch x86_64 -g -D_WIN32_WINNT=1536 -DGRPC_XDS_USER_AGENT_NAME_SUFFIX="Python" -DGRPC_XDS_USER_AGENT_VERSION_SUFFIX="1.50.0" -DOPENSSL_NO_ASM=1 -DGPR_BACKWARDS_COMPATIBILITY_MODE=1 -DHAVE_CONFIG_H=1 -DGRPC_ENABLE_FORK_SUPPORT=1 -DPyMODINIT_FUNC=extern "C" __attribute__((visibility ("default"))) PyObject* -DGRPC_POSIX_FORK_ALLOW_PTHREAD_ATFORK=1 -Isrc/python/grpcio -Iinclude -I. -Ithird_party/abseil-cpp -Ithird_party/address_sorting/include -Ithird_party/cares/cares/include -Ithird_party/cares -Ithird_party/cares/cares -Ithird_party/cares/config_darwin -Ithird_party/re2 -Ithird_party/boringssl-with-bazel/src/include -Ithird_party/upb -Isrc/core/ext/upb-generated -Isrc/core/ext/upbdefs-generated -Ithird_party/xxhash -Ithird_party/zlib -I/Library/Frameworks/Python.framework/Versions/3.10/include/python3.10 -c third_party/re2/util/strutil.cc -o python_build/temp.macosx-10.10-universal2-3.10/third_party/re2/util/strutil.o -std=c++14 -stdlib=libc++ -fvisibility=hidden -fno-wrapv -fno-exceptions -DHAVE_UNISTD_H -pthread
#
#     You have not agreed to the Xcode license agreements, please run 'sudo xcodebuild -license' from within a Terminal window to review and agree to the Xcode license agreements.
#
#     You have not agreed to the Xcode license agreements, please run 'sudo xcodebuild -license' from within a Terminal window to review and agree to the Xcode license agreements.
#
#     You have not agreed to the Xcode license agreements, please run 'sudo xcodebuild -license' from within a Terminal window to review and agree to the Xcode license agreements.
#
#     You have not agreed to the Xcode license agreements, please run 'sudo xcodebuild -license' from within a Terminal window to review and agree to the Xcode license agreements.
#
#     You have not agreed to the Xcode license agreements, please run 'sudo xcodebuild -license' from within a Terminal window to review and agree to the Xcode license agreements.
#
#     You have not agreed to the Xcode license agreements, please run 'sudo xcodebuild -license' from within a Terminal window to review and agree to the Xcode license agreements.
#
#     You have not agreed to the Xcode license agreements, please run 'sudo xcodebuild -license' from within a Terminal window to review and agree to the Xcode license agreements.
#
#     You have not agreed to the Xcode license agreements, please run 'sudo xcodebuild -license' from within a Terminal window to review and agree to the Xcode license agreements.
#     creating None
#     creating None/var
#     creating None/var/folders
#     creating None/var/folders/n3
#     creating None/var/folders/n3/gktccr_97278_m89q24kbjx80000gn
#     creating None/var/folders/n3/gktccr_97278_m89q24kbjx80000gn/T
#     creating None/var/folders/n3/gktccr_97278_m89q24kbjx80000gn/T/tmp0ibh22s8
#     clang -Wno-unused-result -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -arch arm64 -arch x86_64 -g -I/Library/Frameworks/Python.framework/Versions/3.10/include/python3.10 -c /var/folders/n3/gktccr_97278_m89q24kbjx80000gn/T/tmp0ibh22s8/a.c -o None/var/folders/n3/gktccr_97278_m89q24kbjx80000gn/T/tmp0ibh22s8/a.o
#
#     You have not agreed to the Xcode license agreements, please run 'sudo xcodebuild -license' from within a Terminal window to review and agree to the Xcode license agreements.
#
#     Could not find <Python.h>. This could mean the following:
#       * You're on Ubuntu and haven't run `apt-get install python3-dev`.
#       * You're on RHEL/Fedora and haven't run `yum install python3-devel` or
#         `dnf install python3-devel` (make sure you also have redhat-rpm-config
#         installed)
#       * You're on Mac OS X and the usual Python framework was somehow corrupted
#         (check your environment variables or try re-installing?)
#       * You're on Windows and your Python installation was somehow corrupted
#         (check your environment variables or try re-installing?)
#     Traceback (most recent call last):
#       File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/distutils/unixccompiler.py", line 117, in _compile
#         self.spawn(compiler_so + cc_args + [src, '-o', obj] +
#       File "/private/var/folders/n3/gktccr_97278_m89q24kbjx80000gn/T/pip-install-jpnjh75i/grpcio_24fe0bfdd51e47d98e1d829148fb0a6c/src/python/grpcio/_spawn_patch.py", line 54, in _commandfile_spawn
#         _classic_spawn(self, command)
#       File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/distutils/ccompiler.py", line 910, in spawn
#         spawn(cmd, dry_run=self.dry_run)
#       File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/distutils/spawn.py", line 91, in spawn
#         raise DistutilsExecError(
#     distutils.errors.DistutilsExecError: command '/usr/bin/clang' failed with exit code 69
#
#     During handling of the above exception, another exception occurred:
#
#     Traceback (most recent call last):
#       File "/private/var/folders/n3/gktccr_97278_m89q24kbjx80000gn/T/pip-install-jpnjh75i/grpcio_24fe0bfdd51e47d98e1d829148fb0a6c/src/python/grpcio/commands.py", line 280, in build_extensions
#         build_ext.build_ext.build_extensions(self)
#       File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/distutils/command/build_ext.py", line 449, in build_extensions
#         self._build_extensions_serial()
#       File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/distutils/command/build_ext.py", line 474, in _build_extensions_serial
#         self.build_extension(ext)
#       File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/setuptools/command/build_ext.py", line 202, in build_extension
#         _build_ext.build_extension(self, ext)
#       File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/distutils/command/build_ext.py", line 529, in build_extension
#         objects = self.compiler.compile(sources,
#       File "/private/var/folders/n3/gktccr_97278_m89q24kbjx80000gn/T/pip-install-jpnjh75i/grpcio_24fe0bfdd51e47d98e1d829148fb0a6c/src/python/grpcio/_parallel_compile_patch.py", line 58, in _parallel_compile
#         multiprocessing.pool.ThreadPool(BUILD_EXT_COMPILER_JOBS).map(
#       File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/multiprocessing/pool.py", line 364, in map
#         return self._map_async(func, iterable, mapstar, chunksize).get()
#       File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/multiprocessing/pool.py", line 771, in get
#         raise self._value
#       File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#         result = (True, func(*args, **kwds))
#       File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/multiprocessing/pool.py", line 48, in mapstar
#         return list(map(*args))
#       File "/private/var/folders/n3/gktccr_97278_m89q24kbjx80000gn/T/pip-install-jpnjh75i/grpcio_24fe0bfdd51e47d98e1d829148fb0a6c/src/python/grpcio/_parallel_compile_patch.py", line 54, in _compile_single_file
#         self._compile(obj, src, ext, cc_args, extra_postargs, pp_opts)
#       File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/distutils/unixccompiler.py", line 120, in _compile
#         raise CompileError(msg)
#     distutils.errors.CompileError: command '/usr/bin/clang' failed with exit code 69
#
#     During handling of the above exception, another exception occurred:
#
#     Traceback (most recent call last):
#       File "<string>", line 1, in <module>
#       File "/private/var/folders/n3/gktccr_97278_m89q24kbjx80000gn/T/pip-install-jpnjh75i/grpcio_24fe0bfdd51e47d98e1d829148fb0a6c/setup.py", line 540, in <module>
#         setuptools.setup(
#       File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/setuptools/__init__.py", line 153, in setup
#         return distutils.core.setup(**attrs)
#       File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/distutils/core.py", line 148, in setup
#         dist.run_commands()
#       File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/distutils/dist.py", line 966, in run_commands
#         self.run_command(cmd)
#       File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/distutils/dist.py", line 985, in run_command
#         cmd_obj.run()
#       File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/setuptools/command/install.py", line 61, in run
#         return orig.install.run(self)
#       File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/distutils/command/install.py", line 568, in run
#         self.run_command('build')
#       File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/distutils/cmd.py", line 313, in run_command
#         self.distribution.run_command(command)
#       File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/distutils/dist.py", line 985, in run_command
#         cmd_obj.run()
#       File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/distutils/command/build.py", line 135, in run
#         self.run_command(cmd_name)
#       File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/distutils/cmd.py", line 313, in run_command
#         self.distribution.run_command(command)
#       File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/distutils/dist.py", line 985, in run_command
#         cmd_obj.run()
#       File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/setuptools/command/build_ext.py", line 79, in run
#         _build_ext.run(self)
#       File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/distutils/command/build_ext.py", line 340, in run
#         self.build_extensions()
#       File "/private/var/folders/n3/gktccr_97278_m89q24kbjx80000gn/T/pip-install-jpnjh75i/grpcio_24fe0bfdd51e47d98e1d829148fb0a6c/src/python/grpcio/commands.py", line 283, in build_extensions
#         support.diagnose_build_ext_error(self, error, formatted_exception)
#       File "/private/var/folders/n3/gktccr_97278_m89q24kbjx80000gn/T/pip-install-jpnjh75i/grpcio_24fe0bfdd51e47d98e1d829148fb0a6c/src/python/grpcio/support.py", line 117, in diagnose_build_ext_error
#         diagnostic(build_ext, error)
#       File "/private/var/folders/n3/gktccr_97278_m89q24kbjx80000gn/T/pip-install-jpnjh75i/grpcio_24fe0bfdd51e47d98e1d829148fb0a6c/src/python/grpcio/support.py", line 76, in diagnose_compile_error
#         _expect_compile(build_ext.compiler, c_check, message)
#       File "/private/var/folders/n3/gktccr_97278_m89q24kbjx80000gn/T/pip-install-jpnjh75i/grpcio_24fe0bfdd51e47d98e1d829148fb0a6c/src/python/grpcio/support.py", line 68, in _expect_compile
#         raise commands.CommandError(
#     commands.CommandError: Diagnostics found a compilation environment issue:
#
#     Could not find <Python.h>. This could mean the following:
#       * You're on Ubuntu and haven't run `apt-get install python3-dev`.
#       * You're on RHEL/Fedora and haven't run `yum install python3-devel` or
#         `dnf install python3-devel` (make sure you also have redhat-rpm-config
#         installed)
#       * You're on Mac OS X and the usual Python framework was somehow corrupted
#         (check your environment variables or try re-installing?)
#       * You're on Windows and your Python installation was somehow corrupted
#         (check your environment variables or try re-installing?)
#
#     ----------------------------------------
# ERROR: Command errored out with exit status 1: /Library/Frameworks/Python.framework/Versions/3.10/bin/python3.10 -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/n3/gktccr_97278_m89q24kbjx80000gn/T/pip-install-jpnjh75i/grpcio_24fe0bfdd51e47d98e1d829148fb0a6c/setup.py'"'"'; __file__='"'"'/private/var/folders/n3/gktccr_97278_m89q24kbjx80000gn/T/pip-install-jpnjh75i/grpcio_24fe0bfdd51e47d98e1d829148fb0a6c/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record /private/var/folders/n3/gktccr_97278_m89q24kbjx80000gn/T/pip-record-73tcskf_/install-record.txt --single-version-externally-managed --compile --install-headers /Library/Frameworks/Python.framework/Versions/3.10/include/python3.10/grpcio Check the logs for full command output.
# WARNING: You are using pip version 21.2.3; however, version 22.3 is available.
# You should consider upgrading via the '/Library/Frameworks/Python.framework/Versions/3.10/bin/python3.10 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.
